# %% [markdown]
# # Abhishek Gupta

# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Reading Data

# %%
data = pd.read_csv("SampleSuperstore.csv")

# %%
data
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
data.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
data.tail()
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# ...

# %%
data.isnull()#Checing is there any Null Values
# Out:
#       Ship Mode  Segment  Country   City  State  Postal Code  Region  \
# 0         False    False    False  False  False        False   False
# 1         False    False    False  False  False        False   False
# 2         False    False    False  False  False        False   False
# 3         False    False    False  False  False        False   False
# 4         False    False    False  False  False        False   False
# ...         ...      ...      ...    ...    ...          ...     ...
# 9989      False    False    False  False  False        False   False
# 9990      False    False    False  False  False        False   False
# 9991      False    False    False  False  False        False   False
# 9992      False    False    False  False  False        False   False
# 9993      False    False    False  False  False        False   False
#
#       Category  Sub-Category  Sales  Quantity  Discount  Profit
# 0        False         False  False     False     False   False
# ...

# %%
data.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
data.dtypes
# Out:
# Ship Mode        object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %%
data['Sales'].mean()
# Out:
# 229.8580008304938

# %%
data['Sales'].median()
# Out:
# 54.489999999999995

# %%
data['Sales'].mode()
# Out:
# 0    12.96
# dtype: float64

# %%
data['Quantity'].mean()
# Out:
# 3.789573744246548

# %%
data['Quantity'].median()
# Out:
# 3.0

# %%
data['Quantity'].mode()
# Out:
# 0    3
# dtype: int64

# %%
data['Discount'].mean()
# Out:
# 0.15620272163298934

# %%
data['Discount'].median()
# Out:
# 0.2

# %%
data['Discount'].mode()
# Out:
# 0    0.0
# dtype: float64

# %%
data['Profit'].mean()
# Out:
# 28.656896307784802

# %%
data['Profit'].median()
# Out:
# 8.6665

# %%
data['Profit'].mode()
# Out:
# 0    0.0
# dtype: float64

# %%
new_data = data.drop(columns = 'Country')#Dropping Country Column

# %%
new_data
# Out:
#            Ship Mode    Segment             City       State  Postal Code  \
# 0       Second Class   Consumer        Henderson    Kentucky        42420
# 1       Second Class   Consumer        Henderson    Kentucky        42420
# 2       Second Class  Corporate      Los Angeles  California        90036
# 3     Standard Class   Consumer  Fort Lauderdale     Florida        33311
# 4     Standard Class   Consumer  Fort Lauderdale     Florida        33311
# ...              ...        ...              ...         ...          ...
# 9989    Second Class   Consumer            Miami     Florida        33180
# 9990  Standard Class   Consumer       Costa Mesa  California        92627
# 9991  Standard Class   Consumer       Costa Mesa  California        92627
# 9992  Standard Class   Consumer       Costa Mesa  California        92627
# 9993    Second Class   Consumer      Westminster  California        92683
#
#      Region         Category Sub-Category     Sales  Quantity  Discount  \
# ...

# %%
new_data.dtypes
# Out:
# Ship Mode        object
# Segment          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %% [markdown]
# Categorical Data: Ship Mode, Segment, City, State, Postal Code, Region, Category, Sub-Category

# %% [markdown]
# Numerical Data: Sales, Quantity, Discount, Profit

# %% [markdown]
# #### Univariate Analysis of Categorical Data

# %%
#Ship Mode

print(new_data['Ship Mode'].value_counts())
new_data['Ship Mode'].value_counts().plot.bar()
# Out:
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: Ship Mode, dtype: int64
# <AxesSubplot:>

# %%
#Segment

print(new_data['Segment'].value_counts())
new_data['Segment'].value_counts().plot.bar()
# Out:
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: Segment, dtype: int64
# <AxesSubplot:>

# %%
#City

print(new_data['City'].value_counts())
plt.figure(figsize=(50,30))
new_data['City'].value_counts().plot.bar()
# Out:
# New York City    915
# Los Angeles      747
# Philadelphia     537
# San Francisco    510
# Seattle          428
#                 ...
# Danbury            1
# Billings           1
# Davis              1
# Cedar Rapids       1
# Palatine           1
# Name: City, Length: 531, dtype: int64
# <AxesSubplot:>

# %%
#State

print(new_data['State'].value_counts())
plt.figure(figsize=(40,10))
new_data['State'].value_counts().plot.bar()
# Out:
# California              2001
# New York                1128
# Texas                    985
# Pennsylvania             587
# Washington               506
# Illinois                 492
# Ohio                     469
# Florida                  383
# Michigan                 255
# North Carolina           249
# Virginia                 224
# Arizona                  224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   124
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Missouri                  66
# Oklahoma                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Mississippi               53
# Utah                      53
# ...

# %%
#Postal Code

print(new_data['Postal Code'].value_counts())
plt.figure(figsize=(30,5))
new_data['Postal Code'].value_counts().plot.bar()
# Out:
# 10035    263
# 10024    230
# 10009    229
# 94122    203
# 10011    193
#         ...
# 33458      1
# 95616      1
# 48307      1
# 61832      1
# 59102      1
# Name: Postal Code, Length: 631, dtype: int64
# <AxesSubplot:>

# %%
#Region

print(new_data['Region'].value_counts())
new_data['Region'].value_counts().plot.pie()
# Out:
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: Region, dtype: int64
# <AxesSubplot:ylabel='Region'>

# %%
#Category

print(new_data['Category'].value_counts())
new_data['Category'].value_counts().plot.pie()
# Out:
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: Category, dtype: int64
# <AxesSubplot:ylabel='Category'>

# %%
#Sub-Category

print(new_data['Sub-Category'].value_counts())
new_data['Sub-Category'].value_counts().plot.bar()
# Out:
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: Sub-Category, dtype: int64
# <AxesSubplot:>

# %% [markdown]
# 1.Maximum Ship Mode is Standard Class.
#
# 2.Maximum Segment is Consumer.
#
# 3.Maximum number of sales in New York  City.
#
# 4.Maximum number of sales in California State.
#
# 5.Maximum number of sales in Postal Code 10035.
#
# 6.Maximum sales is from West Region and Minimum is from South Region.
#
# 7.Maximum number of sales Category is Office Supplies.
#
# 8.Maximum number of sales Sub-Category is Binders.

# %% [markdown]
# #### Univariate Analysis of Numerical Data

# %%
new_data.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
#Sales

print(new_data['Sales'].value_counts())
plt.figure(figsize=(30,5))
plt.subplots_adjust(left=0.125, bottom=0.1, right=0.9, top=0.9, wspace=0.21, hspace=0.4)

plt.subplot(141)
new_data['Sales'].plot.hist()

plt.subplot(142)
sns.boxplot(data=new_data, x='Sales')
# Out:
# 12.960     56
# 19.440     39
# 15.552     39
# 25.920     36
# 10.368     36
#            ..
# 376.866     1
# 572.800     1
# 3.928       1
# 12.032      1
# 629.640     1
# Name: Sales, Length: 5825, dtype: int64
# <AxesSubplot:xlabel='Sales'>

# %%
#Quantity

plt.figure(figsize = (30,5))
print(new_data['Quantity'].value_counts())
plt.subplot(131)
new_data['Quantity'].value_counts().plot.bar()

plt.subplot(132)
sns.boxplot(data = new_data,x = 'Quantity')
# Out:
# 3     2409
# 2     2402
# 5     1230
# 4     1191
# 1      899
# 7      606
# 6      572
# 9      258
# 8      257
# 10      57
# 11      34
# 14      29
# 13      27
# 12      23
# Name: Quantity, dtype: int64
# <AxesSubplot:xlabel='Quantity'>

# %%
#Discount

plt.figure(figsize = (30,5))
print(new_data['Discount'].value_counts())
plt.subplot(131)
new_data['Discount'].value_counts().plot.bar()

plt.subplot(132)
sns.boxplot(data = new_data,x = 'Discount')
# Out:
# 0.00    4798
# 0.20    3657
# 0.70     418
# 0.80     300
# 0.30     227
# 0.40     206
# 0.60     138
# 0.10      94
# 0.50      66
# 0.15      52
# 0.32      27
# 0.45      11
# Name: Discount, dtype: int64
# <AxesSubplot:xlabel='Discount'>

# %%
#Profit

plt.figure(figsize = (30,5))
print(new_data['Profit'].value_counts())

plt.subplot(132)
sns.boxplot(data = new_data,x = 'Profit')
# Out:
#  0.0000      65
#  6.2208      43
#  9.3312      38
#  5.4432      32
#  3.6288      32
#              ..
# -3.5622       1
# -7.4800       1
#  626.1850     1
# -12.8392      1
#  6.1704       1
# Name: Profit, Length: 7287, dtype: int64
# <AxesSubplot:xlabel='Profit'>

# %%
sns.distplot(data["Profit"], kde=True, hist=True, hist_kws=dict(edgecolor="blue", linewidth=1))
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Profit', ylabel='Density'>

# %%
sns.distplot(data["Sales"], kde=True, hist=True, hist_kws=dict(edgecolor="k", linewidth=1))
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Sales', ylabel='Density'>

# %%
sns.distplot(data["Quantity"], kde=True, hist=True, hist_kws=dict(edgecolor="k", linewidth=1))
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Quantity', ylabel='Density'>

# %%
sns.distplot(data["Discount"], kde=True, hist=True, hist_kws=dict(edgecolor="k", linewidth=1))
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Discount', ylabel='Density'>

# %% [markdown]
# 1)Maximum Sales is between 0 to 5 Thousand
#
# 2)Generally the 2 or 3 Quantities re purchased
#
# 3)Maximum customers got 0.0 Discount
#
# 4)0.0000 Profit from Maximum customers

# %%
#Ship Mode
sns.countplot(x="Ship Mode", data=new_data)
# Out:
# <AxesSubplot:xlabel='Ship Mode', ylabel='count'>

# %%
#Segment
sns.countplot(x="Segment", data=new_data)
# Out:
# <AxesSubplot:xlabel='Segment', ylabel='count'>

# %%
#City
plt.figure(figsize = (40,10))
sns.countplot(x="City", data=new_data)
# Out:
# <AxesSubplot:xlabel='City', ylabel='count'>

# %%
#State
plt.figure(figsize = (40,10))
sns.countplot(x="State", data=new_data)
# Out:
# <AxesSubplot:xlabel='State', ylabel='count'>

# %%
#Category
sns.countplot(x="Category", data=new_data)
# Out:
# <AxesSubplot:xlabel='Category', ylabel='count'>

# %%
#Sub-Category
plt.figure(figsize = (40,10))
sns.countplot(x="Sub-Category", data=new_data)
# Out:
# <AxesSubplot:xlabel='Sub-Category', ylabel='count'>

# %% [markdown]
# #### Bivariate Analysis

# %%
#Discount vs Profit
plt.figure(figsize = (40,5))
plt.subplots_adjust(left=0.125, bottom=0.1, right=0.9, top=0.9, wspace=0.5, hspace=0.2)

plt.subplot(142)
sns.histplot(x = "Discount",y="Profit", data = new_data,color ="blue")


plt.subplot(143)
sns.boxplot(x = "Discount", y = "Profit", data = new_data)
# Out:
# <AxesSubplot:xlabel='Discount', ylabel='Profit'>

# %%
#Quantity vs Profit
plt.figure(figsize = (40,5))
plt.subplots_adjust(left=0.125, bottom=0.1, right=0.9, top=0.9, wspace=0.5, hspace=0.2)

plt.subplot(142)
sns.histplot(x = "Quantity",y="Profit", data = new_data , color = "green")


plt.subplot(143)
sns.boxplot(x = "Quantity", y = "Profit", data = new_data)
# Out:
# <AxesSubplot:xlabel='Quantity', ylabel='Profit'>

# %%
#Sales vs Profit
plt.figure(figsize = (80,20))
plt.subplots_adjust(left=0.125, bottom=0.1, right=0.9, top=0.9, wspace=0.5, hspace=0.2)

plt.subplot(142)
sns.histplot(x = "Sales", data = new_data)

plt.subplot(143)
sns.boxplot(x = "Sales", y = "Profit", data = new_data)
# Out:
# <AxesSubplot:xlabel='Sales', ylabel='Profit'>

# %%
#Region vs Profit
plt.figure(figsize = (40,5))
plt.subplots_adjust(left=0.125, bottom=0.1, right=0.9, top=0.9, wspace=0.5, hspace=0.2)

plt.subplot(142)
sns.histplot(x = "Region", data = new_data, color = "red")


plt.subplot(143)
sns.boxplot(x = "Region", y = "Profit", data = new_data)
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Profit'>

# %%
#Category vs Profit
plt.figure(figsize = (40,5))
plt.subplots_adjust(left=0.125, bottom=0.1, right=0.9, top=0.9, wspace=0.5, hspace=0.2)

plt.subplot(142)
sns.histplot(x ="Category",data = new_data)

plt.subplot(143)
sns.boxplot(x = "Category", y = "Profit", data = new_data)
# Out:
# <AxesSubplot:xlabel='Category', ylabel='Profit'>

# %%
plt.figure(figsize = (80,10))
plt.subplots_adjust(left=0.125, bottom=0.1, right=0.9, top=0.9, wspace=0.5, hspace=0.2)

plt.subplot(142)
sns.histplot(x ="Sub-Category",data = new_data)
# Out:
# <AxesSubplot:xlabel='Sub-Category', ylabel='Count'>

# %%
#Sub-Category
plt.figure(figsize = (80,10))
plt.subplot(143)
sns.boxplot(x = "Sub-Category", y = "Profit", data = new_data)
# Out:
# <AxesSubplot:xlabel='Sub-Category', ylabel='Profit'>

# %%
#City
plt.figure(figsize = (900,10))
plt.subplots_adjust(left=0.125, bottom=0.1, right=0.9, top=0.9, wspace=0.5, hspace=0.2)

plt.subplot(142)
sns.histplot(x ="City",data = new_data)
# Out:
# <AxesSubplot:xlabel='City', ylabel='Count'>

# %%
#City vs Profit
plt.figure(figsize = (400,30))
plt.subplot(143)
sns.boxplot(x = "City", y = "Profit", data = new_data)
# Out:
# <AxesSubplot:xlabel='City', ylabel='Profit'>

# %%
#State
plt.figure(figsize = (400,40))
plt.subplots_adjust(left=0.125, bottom=0.1, right=0.9, top=0.9, wspace=0.5, hspace=0.2)

plt.subplot(142)
sns.histplot(x ="State",data = new_data)
# Out:
# <AxesSubplot:xlabel='State', ylabel='Count'>

# %%
#State vs Profit
plt.figure(figsize = (200,30))
plt.subplot(143)
sns.boxplot(x = "State", y = "Profit", data = new_data)
# Out:
# <AxesSubplot:xlabel='State', ylabel='Profit'>

# %% [markdown]
# ## Thank You
